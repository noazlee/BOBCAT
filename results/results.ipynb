# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("question_selection_log.csv", 
                       skiprows=lambda i: i>0 and np.random.random() > 0.1)  # ~10% sample

# %%
df
# Out:
#           epoch  batch_idx  user_id  q_ids  subject_ids  labels
# 0             0        NaN        1    213            1     NaN
# 1             0        NaN        1    370            0     NaN
# 2             0        NaN        2     31            0     NaN
# 3             0        NaN        2    249            1     NaN
# 4             0        NaN        2    267            1     NaN
# ...         ...        ...      ...    ...          ...     ...
# 14879495   1021        NaN      511    362            0     NaN
# 14879496   1021        NaN      511    396            1     NaN
# 14879497   1021        NaN      511    642            0     NaN
# 14879498   1021        NaN      511    658            0     NaN
# 14879499   1021        NaN      511    787            0     NaN
#
# [14879500 rows x 6 columns]

# %%
df['user_id'].value_counts()
# Out:
# user_id
# 67     30088
# 21     29833
# 349    29794
# 324    29782
# 447    29750
#        ...
# 381    28337
# 156    28337
# 426    28305
# 18     28144
# 101    28048
# Name: count, Length: 512, dtype: int64

# %%
df['q_ids'].value_counts()
# Out:
# q_ids
# 199    32296
# 89     31692
# 911    31656
# 922    31583
# 668    31481
#        ...
# 603       30
# 499       28
# 847       27
# 810       26
# 832       24
# Name: count, Length: 948, dtype: int64
